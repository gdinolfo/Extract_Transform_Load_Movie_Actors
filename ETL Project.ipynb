# %%
#import dependencies
import pandas as pd
import json
from bs4 import BeautifulSoup
import requests
import re
import sqlalchemy
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')

# %%
#create function that will turn JSON encoded data into Python objects.
def load_credits(path):
    df = pd.read_csv(path)
    json_columns = ['cast']
    for column in json_columns:
        df[column] = df[column].apply(json.loads)
    return df

# %%
#load csv dataset
credits = load_credits('movies.csv')
credits.head(5)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1  [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 3  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 4  [{'cast_id': 5, 'character': 'John Carter', 'c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
#find keyvalues for cast column
print(sorted(credits.cast.iloc[0][0].keys()))
# Out:
# ['cast_id', 'character', 'credit_id', 'gender', 'id', 'name', 'order']

# %%
#create list of actor
actor_name = [actor['name'] for actor in credits['cast'].iloc[0]]

# %%
#function to grab lead actor in each movie
def get_lead_actor(container, index_values):
    # return a missing value rather than an error upon indexing/key failure
    result = container
    try:
        for idx in index_values:
            result = result[idx]
        return result
    except IndexError or KeyError:
        return pd.np.nan

# %%
credits['lead_actor'] = credits.cast.apply(lambda x: get_lead_actor(x, [0, 'name']))
credits.head(3)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1  [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2  [{'cast_id': 1, 'character': 'James Bond', 'cr...
#
#                                                 crew       lead_actor
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...  Sam Worthington
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...      Johnny Depp
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...     Daniel Craig

# %%
#reduce the size of dataframe to 10 movies
credits20 = credits.head(20)

# %%
#cleanup dataframe
movies_df = credits20.drop(['movie_id', 'cast', 'crew'], axis = 1)

# %%
movies_df
# Out:
#                                           title         lead_actor
# 0                                        Avatar    Sam Worthington
# 1      Pirates of the Caribbean: At World's End        Johnny Depp
# 2                                       Spectre       Daniel Craig
# 3                         The Dark Knight Rises     Christian Bale
# 4                                   John Carter      Taylor Kitsch
# 5                                  Spider-Man 3      Tobey Maguire
# 6                                       Tangled       Zachary Levi
# 7                       Avengers: Age of Ultron  Robert Downey Jr.
# 8        Harry Potter and the Half-Blood Prince   Daniel Radcliffe
# 9            Batman v Superman: Dawn of Justice        Ben Affleck
# 10                             Superman Returns      Brandon Routh
# 11                            Quantum of Solace       Daniel Craig
# 12   Pirates of the Caribbean: Dead Man's Chest        Johnny Depp
# 13                              The Lone Ranger        Johnny Depp
# 14                                 Man of Steel       Henry Cavill
# 15     The Chronicles of Narnia: Prince Caspian         Ben Barnes
# 16                                 The Avengers  Robert Downey Jr.
# 17  Pirates of the Caribbean: On Stranger Tides        Johnny Depp
# 18                               Men in Black 3         Will Smith
# 19    The Hobbit: The Battle of the Five Armies     Martin Freeman

# %%
#function to scrape wikipedia.org for each actor, grabbing birthday, nickname(which is really full name), and birthplace
def to_scrape(url):
    try:
        headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36'}
        resp = requests.get(url, headers=headers)
        soup = BeautifulSoup(resp.content, 'html.parser')
        bday = soup.find('span', {'class': 'bday'}).text
        nickname = soup.find('div', {'class': 'nickname'}).text
        birthplace = soup.find('div', {'class': 'birthplace'}).text
        return {'Birthday': bday, 'Nickname': nickname, 'Birthplace': birthplace}
    except:
        return {'Birthday': None, 'Nickname': None, 'Birthplace': None}

# %%
#create a url with actor name for wikipedia
movies_df['URL'] = movies_df['lead_actor'].map(lambda x: 'https://en.wikipedia.org/wiki/' + x.replace(' ', '_'))

# %%
#scrape wikipedia
movies_df['WikiData'] = movies_df['URL'].map(to_scrape)

# %%
#add fields to dataframe
movies_df['Birthday'] = movies_df['WikiData'].map(lambda x : x.get('Birthday'))
movies_df['Full Name'] = movies_df['WikiData'].map(lambda x : x.get('Nickname'))
movies_df['Birthplace'] = movies_df['WikiData'].map(lambda x : x.get('Birthplace'))

# %%
movies_df
# Out:
#                                           title         lead_actor  \
# 0                                        Avatar    Sam Worthington
# 1      Pirates of the Caribbean: At World's End        Johnny Depp
# 2                                       Spectre       Daniel Craig
# 3                         The Dark Knight Rises     Christian Bale
# 4                                   John Carter      Taylor Kitsch
# 5                                  Spider-Man 3      Tobey Maguire
# 6                                       Tangled       Zachary Levi
# 7                       Avengers: Age of Ultron  Robert Downey Jr.
# 8        Harry Potter and the Half-Blood Prince   Daniel Radcliffe
# 9            Batman v Superman: Dawn of Justice        Ben Affleck
# 10                             Superman Returns      Brandon Routh
# 11                            Quantum of Solace       Daniel Craig
# 12   Pirates of the Caribbean: Dead Man's Chest        Johnny Depp
# 13                              The Lone Ranger        Johnny Depp
# 14                                 Man of Steel       Henry Cavill
# 15     The Chronicles of Narnia: Prince Caspian         Ben Barnes
# 16                                 The Avengers  Robert Downey Jr.
# 17  Pirates of the Caribbean: On Stranger Tides        Johnny Depp
# 18                               Men in Black 3         Will Smith
# 19    The Hobbit: The Battle of the Five Armies     Martin Freeman
#
#                                                 URL  \
# 0     https://en.wikipedia.org/wiki/Sam_Worthington
# 1         https://en.wikipedia.org/wiki/Johnny_Depp
# 2        https://en.wikipedia.org/wiki/Daniel_Craig
# 3      https://en.wikipedia.org/wiki/Christian_Bale
# 4       https://en.wikipedia.org/wiki/Taylor_Kitsch
# 5       https://en.wikipedia.org/wiki/Tobey_Maguire
# 6        https://en.wikipedia.org/wiki/Zachary_Levi
# 7   https://en.wikipedia.org/wiki/Robert_Downey_Jr.
# 8    https://en.wikipedia.org/wiki/Daniel_Radcliffe
# 9         https://en.wikipedia.org/wiki/Ben_Affleck
# 10      https://en.wikipedia.org/wiki/Brandon_Routh
# 11       https://en.wikipedia.org/wiki/Daniel_Craig
# 12        https://en.wikipedia.org/wiki/Johnny_Depp
# 13        https://en.wikipedia.org/wiki/Johnny_Depp
# 14       https://en.wikipedia.org/wiki/Henry_Cavill
# 15         https://en.wikipedia.org/wiki/Ben_Barnes
# 16  https://en.wikipedia.org/wiki/Robert_Downey_Jr.
# 17        https://en.wikipedia.org/wiki/Johnny_Depp
# 18         https://en.wikipedia.org/wiki/Will_Smith
# 19     https://en.wikipedia.org/wiki/Martin_Freeman
#
#                                              WikiData    Birthday  \
# 0   {'Birthday': '1976-08-02', 'Nickname': 'Samuel...  1976-08-02
# 1   {'Birthday': '1963-06-09', 'Nickname': 'John C...  1963-06-09
# 2   {'Birthday': '1968-03-02', 'Nickname': 'Daniel...  1968-03-02
# 3   {'Birthday': '1974-01-30', 'Nickname': 'Christ...  1974-01-30
# 4   {'Birthday': None, 'Nickname': None, 'Birthpla...        None
# 5   {'Birthday': '1975-06-27', 'Nickname': 'Tobias...  1975-06-27
# 6   {'Birthday': '1980-09-29', 'Nickname': 'Zachar...  1980-09-29
# 7   {'Birthday': '1965-04-04', 'Nickname': 'Robert...  1965-04-04
# 8   {'Birthday': '1989-07-23', 'Nickname': 'Daniel...  1989-07-23
# 9   {'Birthday': '1972-08-15', 'Nickname': 'Benjam...  1972-08-15
# 10  {'Birthday': '1979-10-09', 'Nickname': 'Brando...  1979-10-09
# 11  {'Birthday': '1968-03-02', 'Nickname': 'Daniel...  1968-03-02
# 12  {'Birthday': '1963-06-09', 'Nickname': 'John C...  1963-06-09
# 13  {'Birthday': '1963-06-09', 'Nickname': 'John C...  1963-06-09
# 14  {'Birthday': '1983-05-05', 'Nickname': 'Henry ...  1983-05-05
# 15  {'Birthday': None, 'Nickname': None, 'Birthpla...        None
# 16  {'Birthday': '1965-04-04', 'Nickname': 'Robert...  1965-04-04
# 17  {'Birthday': '1963-06-09', 'Nickname': 'John C...  1963-06-09
# 18  {'Birthday': '1968-09-25', 'Nickname': 'Willar...  1968-09-25
# 19  {'Birthday': '1971-09-08', 'Nickname': 'Martin...  1971-09-08
#
#                           Full Name                           Birthplace
# 0     Samuel Henry John Worthington       Godalming, Surrey, England, UK
# 1          John Christopher Depp II            Owensboro, Kentucky, U.S.
# 2            Daniel Wroughton Craig           Chester, Cheshire, England
# 3     Christian Charles Philip Bale  Haverfordwest, Pembrokeshire, Wales
# 4                              None                                 None
# 5            Tobias Vincent Maguire       Santa Monica, California, U.S.
# 6                 Zachary Levi Pugh        Lake Charles, Louisiana, U.S.
# 7            Robert John Downey Jr.        New York City, New York, U.S.
# 8            Daniel Jacob Radcliffe                      London, England
# 9       Benjamin Géza Affleck-Boldt           Berkeley, California, U.S.
# 10              Brandon James Routh                  Norwalk, Iowa, U.S.
# 11           Daniel Wroughton Craig           Chester, Cheshire, England
# 12         John Christopher Depp II            Owensboro, Kentucky, U.S.
# 13         John Christopher Depp II            Owensboro, Kentucky, U.S.
# 14   Henry William Dalgliesh Cavill                 Saint Helier, Jersey
# 15                             None                                 None
# 16           Robert John Downey Jr.        New York City, New York, U.S.
# 17         John Christopher Depp II            Owensboro, Kentucky, U.S.
# 18         Willard Carroll Smith II     Philadelphia, Pennsylvania, U.S.
# 19  Martin John Christopher Freeman        Aldershot, Hampshire, England

# %%
#create sqlite engine
engine = create_engine("sqlite:///movieactors.sqlite")

# %%
#drop wikipedia info dictionary
movies_final = movies_df.drop(['WikiData'], axis=1)

# %%
#load movies_final dataframe to sqlite
import sqlite3

conn = sqlite3.connect('movieactors.sqlite')

movies_final.to_sql('tab', conn, if_exists='replace', index=False)
